# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

df = pd.read_csv("files\House_Data.csv")

df['size'] = df['size'].astype(str).str.extract('(\d+)').astype(float)

print(df)

null_values = df.isnull().sum()
has_duplicates = df.duplicated().any()

if null_values.sum() != 0:
   df.dropna(inplace=True)
   

if has_duplicates:
   df.drop_duplicates(inplace=True)
   
df = df[df['availability'] != 'Ready To Move'] 





print(df )

_df = df.select_dtypes(include=['number'])

Q1 = _df.quantile(0.25)
Q3 = _df.quantile(0.75)
IQR = Q3 - Q1

outliers = ((_df < (Q1 - 1.5 * IQR)) | (_df> (Q3 + 1.5 * IQR)))

_df[outliers].dropna()





df_cleaned = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_cleaned.head()


plt.figure(figsize=(10, 5))
sns.boxplot(data=df)
plt.show()

print(df)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\H'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\H'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\win10\AppData\Local\Temp\ipykernel_880\2212899957.py:8: SyntaxWarning: invalid escape sequence '\H'
#   df = pd.read_csv("files\House_Data.csv")
# C:\Users\win10\AppData\Local\Temp\ipykernel_880\2212899957.py:10: SyntaxWarning: invalid escape sequence '\d'
#   df['size'] = df['size'].astype(str).str.extract('(\d+)').astype(float)
#                   area_type   availability  size  society total_sqft  bath  \
# 0      Super built-up  Area         19-Dec   2.0  Coomee        1056   2.0
# 1                Plot  Area  Ready To Move   4.0  Theanmp       2600   5.0
# 2            Built-up  Area  Ready To Move   3.0      NaN       1440   2.0
# 3      Super built-up  Area  Ready To Move   3.0  Soiewre       1521   3.0
# 4      Super built-up  Area  Ready To Move   2.0      NaN       1200   2.0
# ...                     ...            ...   ...      ...        ...   ...
# 13315        Built-up  Area  Ready To Move   5.0  ArsiaEx       3453   4.0
# 13316  Super built-up  Area  Ready To Move   4.0      NaN       3600   5.0
# 13317        Built-up  Area  Ready To Move   2.0  Mahla T       1141   2.0
# 13318  Super built-up  Area         18-Jun   4.0  SollyCl       4689   4.0
# 13319  Super built-up  Area  Ready To Move   1.0      NaN        550   1.0
#
#        balcony   price         site_location
# 0          1.0   39.07           Alandi Road
# 1          3.0  120.00       Ambegaon Budruk
# 2          3.0   62.00            Anandnagar
# 3          1.0   95.00                 Aundh
# 4          1.0   51.00            Aundh Road
# ...        ...     ...                   ...
# 13315      0.0  231.00                Pashan
# 13316      NaN  400.00             Paud Road
# 13317      1.0   60.00              Pirangut
# 13318      1.0  488.00          Prabhat Road
# 13319      1.0   17.00  Pune Railway Station
#
# [13320 rows x 9 columns]
#                   area_type availability  size  society   total_sqft  bath  \
# 0      Super built-up  Area       19-Dec   2.0  Coomee          1056   2.0
# 21     Super built-up  Area       19-Dec   3.0  She 2rk         1755   3.0
# 24     Super built-up  Area       18-Nov   1.0  Bhe 2ko          510   1.0
# 28     Super built-up  Area       17-Oct   2.0  ViistLa         1151   2.0
# 30     Super built-up  Area       19-Dec   4.0  LedorSa  2100 - 2850   4.0
# ...                     ...          ...   ...      ...          ...   ...
# 13282  Super built-up  Area       18-Apr   3.0  PuendWe         1919   3.0
# 13292  Super built-up  Area       18-Jul   3.0  Plowsri         1440   2.0
# 13295  Super built-up  Area       18-Feb   3.0  SNnia E         1810   3.0
# 13299  Super built-up  Area       18-Dec   4.0  Prtates  2830 - 2882   5.0
# 13318  Super built-up  Area       18-Jun   4.0  SollyCl         4689   4.0
#
#        balcony   price               site_location
# 0          1.0   39.07                 Alandi Road
# 21         1.0  122.00            Dhole Patil Road
# 24         0.0   25.25      Fergusson College Road
# 28         2.0   48.77                       other
# 30         0.0  186.00                    Gultekdi
# ...        ...     ...                         ...
# 13282      2.0  117.00  Hadapsar Industrial Estate
# 13292      2.0   63.93                     Kharadi
# 13295      2.0  112.00               Kondhwa Khurd
# 13299      0.0  154.50                  Laxmi Road
# 13318      1.0  488.00                Prabhat Road
#
# [1786 rows x 9 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 46
#      38 outliers = ((_df < (Q1 - 1.5 * IQR)) | (_df> (Q3 + 1.5 * IQR)))
#      40 _df[outliers].dropna()
# ---> 46 df_cleaned = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
#      47 df_cleaned.head()
#      50 plt.figure(figsize=(10, 5))
#
# File c:\software\Python\Python312\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\software\Python\Python312\Lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File c:\software\Python\Python312\Lib\site-packages\pandas\core\frame.py:7897, in DataFrame._cmp_method(self, other, op)
#    7894 def _cmp_method(self, other, op):
#    7895     axis: Literal[1] = 1  # only relevant for Series other case
# -> 7897     self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7899     # See GH#4537 for discussion of scalar op behavior
#    7900     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File c:\software\Python\Python312\Lib\site-packages\pandas\core\frame.py:8205, in DataFrame._align_for_op(self, other, axis, flex, level)
#    8203 if not flex:
#    8204     if not left.axes[axis].equals(right.index):
# -> 8205         raise ValueError(
#    8206             "Operands are not aligned. Do "
#    8207             "`left, right = left.align(right, axis=1, copy=False)` "
#    8208             "before operating."
#    8209         )
#    8211 left, right = left.align(
#    8212     right,
#    8213     join="outer",
#    (...)
#    8216     copy=False,
#    8217 )
#    8218 right = left._maybe_align_series_as_frame(right, axis)
#
# ValueError: Operands are not aligned. Do `left, right = left.align(right, axis=1, copy=False)` before operating.
