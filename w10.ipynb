# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
tips = pd.read_csv('week10/Sample_Data_for_Activity.csv')
tips.head()
tips.info()
sns.displot(tips['Normal_Distribution'], kde=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Normal_Distribution       1000 non-null   float64
#  1   Uniform_Distribution      1000 non-null   float64
#  2   Exponential_Distribution  1000 non-null   float64
#  3   Poisson_Distribution      1000 non-null   int64
# dtypes: float64(3), int64(1)
# memory usage: 31.4 KB

# %%
sns.displot(tips['Normal_Distribution'], kde=True, bins=100)

# %%
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=tips, kind='scatter')

# %%
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=tips, kind='reg')

# %%
sns.jointplot(x='Normal_Distribution', y='Uniform_Distribution', data=tips, kind='hex')

# %%
sns.pairplot(tips, hue="Exponential_Distribution")

# %%
sns.displot(tips['Normal_Distribution'], kind="hist", kde=True, bins=20)
sns.rugplot(tips['Normal_Distribution'], color="r")
# Out:
# <Axes: xlabel='Normal_Distribution', ylabel='Count'>

# %%
sns.kdeplot(tips['Normal_Distribution'])
sns.rugplot(tips['Normal_Distribution'])
# Out:
# <Axes: xlabel='Normal_Distribution', ylabel='Density'>

# %%
sns.pairplot(
    penguins,
    x_vars=["bill_length_mm", "bill_depth_mm", "flipper_length_mm"],
    y_vars=["bill_length_mm", "bill_depth_mm"],
    hue="species"
)
